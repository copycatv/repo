# %% [markdown]
# Data Cleaning on population data, gender ratio, age structure and employment rate from 2000-2022/2023
#
# Source: Labour force and employment https://www.censtatd.gov.hk/tc/web_table.html?id=210-06101#
#
# Age structure: https://www.censtatd.gov.hk/tc/web_table.html?id=1B#
#
# Gender ratio: https://www.censtatd.gov.hk/tc/web_table.html?id=110-01005#
#
#
# After modify version = https://drive.google.com/drive/folders/1kA73MvIfD3HQanfOmMbvOHTVLwPzcA4b

# %%
import pandas as pd
from google.colab import files

employment_rate =  pd.read_csv('labor_force.csv')
age_structure = pd.read_csv('age_structure.csv')
gender_ratio = pd.read_csv('gender_ratio.csv')

# %%
employment_rate
# Out:
#     STAT_VAR        STAT_PRES  CCYY  M3M  SEX  OBS_VALUE  SD_VALUE
# 0         LF  Raw_K_1dp_per_n  2000  NaN    M     1964.0       NaN
# 1         LF  Raw_K_1dp_per_n  2000  NaN    F     1410.2       NaN
# 2         LF  Raw_K_1dp_per_n  2000  NaN  NaN     3374.2       NaN
# 3         UR     Rate_1dp_%_n  2000  NaN    M        5.6       NaN
# 4         UR     Rate_1dp_%_n  2000  NaN    F        4.1       NaN
# ..       ...              ...   ...  ...  ...        ...       ...
# 202       UR     Rate_1dp_%_n  2022  NaN    F        3.5       NaN
# 203       UR     Rate_1dp_%_n  2022  NaN  NaN        4.3       NaN
# 204       EM  Raw_K_1dp_per_n  2022  NaN    M     1789.5       NaN
# 205       EM  Raw_K_1dp_per_n  2022  NaN    F     1823.7       NaN
# 206       EM  Raw_K_1dp_per_n  2022  NaN  NaN     3613.2       NaN
#
# [207 rows x 7 columns]

# %%
employment_rate_cal = employment_rate[(employment_rate['STAT_VAR'] !='UR') ].drop(['SD_VALUE','STAT_PRES','M3M','SEX'], axis=1)
employment_rate_cal
# Out:
#     STAT_VAR  CCYY  OBS_VALUE
# 0         LF  2000     1964.0
# 1         LF  2000     1410.2
# 2         LF  2000     3374.2
# 6         EM  2000     1854.5
# 7         EM  2000     1352.8
# ..       ...   ...        ...
# 199       LF  2022     1890.3
# 200       LF  2022     3776.3
# 204       EM  2022     1789.5
# 205       EM  2022     1823.7
# 206       EM  2022     3613.2
#
# [138 rows x 3 columns]

# %%
employment_rate_cal = employment_rate_cal[employment_rate_cal['OBS_VALUE']>3000]
employment_rate_cal
# Out:
#     STAT_VAR  CCYY  OBS_VALUE
# 2         LF  2000     3374.2
# 8         EM  2000     3207.3
# 11        LF  2001     3427.3
# 17        EM  2001     3252.9
# 20        LF  2002     3472.6
# 26        EM  2002     3218.4
# 29        LF  2003     3465.8
# 35        EM  2003     3190.6
# 38        LF  2004     3512.8
# 44        EM  2004     3273.5
# 47        LF  2005     3534.2
# 53        EM  2005     3336.6
# 56        LF  2006     3571.8
# 62        EM  2006     3400.8
# 65        LF  2007     3622.3
# 71        EM  2007     3476.9
# 74        LF  2008     3637.2
# 80        EM  2008     3509.1
# 83        LF  2009     3660.3
# 89        EM  2009     3467.6
# 92        LF  2010     3631.3
# 98        EM  2010     3474.1
# 101       LF  2011     3703.1
# 107       EM  2011     3576.4
# 110       LF  2012     3782.2
# 116       EM  2012     3658.0
# 119       LF  2013     3855.1
# 125       EM  2013     3724.0
# 128       LF  2014     3871.1
# 134       EM  2014     3743.5
# 137       LF  2015     3903.2
# 143       EM  2015     3773.8
# 146       LF  2016     3920.1
# 152       EM  2016     3787.1
# 155       LF  2017     3956.0
# 161       EM  2017     3832.4
# 164       LF  2018     3996.8
# 170       EM  2018     3884.6
# 173       LF  2019     3987.8
# 179       EM  2019     3871.4
# 182       LF  2020     3918.5
# 188       EM  2020     3690.9
# 191       LF  2021     3870.4
# 197       EM  2021     3670.2
# 200       LF  2022     3776.3
# 206       EM  2022     3613.2

# %%
df_LF = employment_rate_cal.groupby(employment_rate_cal.STAT_VAR).get_group('LF')
df_EM = employment_rate_cal.groupby(employment_rate_cal.STAT_VAR).get_group('EM')

# %%
df_EM_merge = pd.concat([df_LF, df_EM],ignore_index=True, sort=False)
df_EM_merge
# Out:
#    STAT_VAR  CCYY  OBS_VALUE
# 0        LF  2000     3374.2
# 1        LF  2001     3427.3
# 2        LF  2002     3472.6
# 3        LF  2003     3465.8
# 4        LF  2004     3512.8
# 5        LF  2005     3534.2
# 6        LF  2006     3571.8
# 7        LF  2007     3622.3
# 8        LF  2008     3637.2
# 9        LF  2009     3660.3
# 10       LF  2010     3631.3
# 11       LF  2011     3703.1
# 12       LF  2012     3782.2
# 13       LF  2013     3855.1
# 14       LF  2014     3871.1
# 15       LF  2015     3903.2
# 16       LF  2016     3920.1
# 17       LF  2017     3956.0
# 18       LF  2018     3996.8
# 19       LF  2019     3987.8
# 20       LF  2020     3918.5
# 21       LF  2021     3870.4
# 22       LF  2022     3776.3
# 23       EM  2000     3207.3
# 24       EM  2001     3252.9
# 25       EM  2002     3218.4
# 26       EM  2003     3190.6
# 27       EM  2004     3273.5
# 28       EM  2005     3336.6
# 29       EM  2006     3400.8
# 30       EM  2007     3476.9
# 31       EM  2008     3509.1
# 32       EM  2009     3467.6
# 33       EM  2010     3474.1
# 34       EM  2011     3576.4
# 35       EM  2012     3658.0
# 36       EM  2013     3724.0
# 37       EM  2014     3743.5
# 38       EM  2015     3773.8
# 39       EM  2016     3787.1
# 40       EM  2017     3832.4
# 41       EM  2018     3884.6
# 42       EM  2019     3871.4
# 43       EM  2020     3690.9
# 44       EM  2021     3670.2
# 45       EM  2022     3613.2

# %%
s = []
for i in range(len(df_LF)):
  a = df_EM_merge['OBS_VALUE'][i+23]/ df_EM_merge['OBS_VALUE'][i]*100
  s.append(a)

# %%
df_LF['employment_rate'] =  s
df_LF
# employment_rate from 2000-2022
# Out:
# <ipython-input-38-900254ac3a25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_LF['employment_rate'] =  s
#     STAT_VAR  CCYY  OBS_VALUE  employment_rate
# 2         LF  2000     3374.2        95.053642
# 11        LF  2001     3427.3        94.911446
# 20        LF  2002     3472.6        92.679836
# 29        LF  2003     3465.8        92.059553
# 38        LF  2004     3512.8        93.187770
# 47        LF  2005     3534.2        94.408919
# 56        LF  2006     3571.8        95.212498
# 65        LF  2007     3622.3        95.985976
# 74        LF  2008     3637.2        96.478060
# 83        LF  2009     3660.3        94.735404
# 92        LF  2010     3631.3        95.670972
# 101       LF  2011     3703.1        96.578542
# 110       LF  2012     3782.2        96.716197
# 119       LF  2013     3855.1        96.599310
# 128       LF  2014     3871.1        96.703779
# 137       LF  2015     3903.2        96.684771
# 146       LF  2016     3920.1        96.607229
# 155       LF  2017     3956.0        96.875632
# 164       LF  2018     3996.8        97.192754
# 173       LF  2019     3987.8        97.081097
# 182       LF  2020     3918.5        94.191655
# 191       LF  2021     3870.4        94.827408
# 200       LF  2022     3776.3        95.680958

# %%
age_structure
# Out:
#      STAT_VAR     STAT_PRES SEX   AGE  CCYY  H  OBS_VALUE  SD_VALUE
# 0         POP  Prop_1dp_%_n   M  zero  2000  2        0.4       NaN
# 1         POP  Prop_1dp_%_n   M  zero  2001  2        0.3       NaN
# 2         POP  Prop_1dp_%_n   M  zero  2002  2        0.3       NaN
# 3         POP  Prop_1dp_%_n   M  zero  2003  2        0.3       NaN
# 4         POP  Prop_1dp_%_n   M  zero  2004  2        0.3       NaN
# ...       ...           ...  ..   ...   ... ..        ...       ...
# 3997      POP  Prop_1dp_%_n   F   NaN  2018  2       54.3       NaN
# 3998      POP  Prop_1dp_%_n   F   NaN  2019  2       54.4       NaN
# 3999      POP  Prop_1dp_%_n   F   NaN  2020  2       54.4       NaN
# 4000      POP  Prop_1dp_%_n   F   NaN  2021  2       54.4       NaN
# 4001      POP  Prop_1dp_%_n   F   NaN  2022  2       54.4       NaN
#
# [4002 rows x 8 columns]

# %%
df_age = age_structure.drop(['STAT_VAR','STAT_PRES','SD_VALUE','H'], axis=1)
df_age = df_age.dropna(subset=['SEX'])
df_age = df_age.replace('zero', 0)
df_age
# Out:
#      SEX  AGE  CCYY  OBS_VALUE
# 0      M    0  2000        0.4
# 1      M    0  2001        0.3
# 2      M    0  2002        0.3
# 3      M    0  2003        0.3
# 4      M    0  2004        0.3
# ...   ..  ...   ...        ...
# 3997   F  NaN  2018       54.3
# 3998   F  NaN  2019       54.4
# 3999   F  NaN  2020       54.4
# 4000   F  NaN  2021       54.4
# 4001   F  NaN  2022       54.4
#
# [4002 rows x 4 columns]

# %%
df_age.AGE.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3997     True
# 3998     True
# 3999     True
# 4000     True
# 4001     True
# Name: AGE, Length: 4002, dtype: bool

# %%
df_2000 = df_age.loc[df_age['CCYY']== 2000]
df_2000
# Out:
#      SEX  AGE  CCYY  OBS_VALUE
# 0      M    0  2000        0.4
# 23     M    1  2000        0.4
# 46     M    2  2000        0.4
# 69     M    3  2000        0.5
# 92     M    4  2000        0.5
# ...   ..  ...   ...        ...
# 3887   F   82  2000        0.1
# 3910   F   83  2000        0.1
# 3933   F   84  2000        0.1
# 3956   F  85+  2000        0.6
# 3979   F  NaN  2000       51.0
#
# [174 rows x 4 columns]

# %%
df_tot = df_age.fillna('all')
df_tot = df_tot.loc[df_tot['AGE']== 'all']
df_tot
# Out:
#      SEX  AGE  CCYY  OBS_VALUE
# 1978   M  all  2000       49.0
# 1979   M  all  2001       48.8
# 1980   M  all  2002       48.6
# 1981   M  all  2003       48.3
# 1982   M  all  2004       48.1
# 1983   M  all  2005       47.8
# 1984   M  all  2006       47.6
# 1985   M  all  2007       47.4
# 1986   M  all  2008       47.2
# 1987   M  all  2009       47.0
# 1988   M  all  2010       46.8
# 1989   M  all  2011       46.6
# 1990   M  all  2012       46.5
# 1991   M  all  2013       46.3
# 1992   M  all  2014       46.2
# 1993   M  all  2015       46.1
# 1994   M  all  2016       46.0
# 1995   M  all  2017       45.8
# 1996   M  all  2018       45.7
# 1997   M  all  2019       45.6
# 1998   M  all  2020       45.6
# 1999   M  all  2021       45.6
# 2000   M  all  2022       45.6
# 3979   F  all  2000       51.0
# 3980   F  all  2001       51.2
# 3981   F  all  2002       51.4
# 3982   F  all  2003       51.7
# 3983   F  all  2004       51.9
# 3984   F  all  2005       52.2
# 3985   F  all  2006       52.4
# 3986   F  all  2007       52.6
# 3987   F  all  2008       52.8
# 3988   F  all  2009       53.0
# 3989   F  all  2010       53.2
# 3990   F  all  2011       53.4
# 3991   F  all  2012       53.5
# 3992   F  all  2013       53.7
# 3993   F  all  2014       53.8
# 3994   F  all  2015       53.9
# 3995   F  all  2016       54.0
# 3996   F  all  2017       54.2
# 3997   F  all  2018       54.3
# 3998   F  all  2019       54.4
# 3999   F  all  2020       54.4
# 4000   F  all  2021       54.4
# 4001   F  all  2022       54.4

# %%
df_male_ratio = df_tot.groupby('SEX').get_group('M')
df_female_ratio = df_tot.groupby('SEX').get_group('F')
# male/ female ratio

# %%
df_male_ratio
# Out:
#      SEX  AGE  CCYY  OBS_VALUE
# 1978   M  all  2000       49.0
# 1979   M  all  2001       48.8
# 1980   M  all  2002       48.6
# 1981   M  all  2003       48.3
# 1982   M  all  2004       48.1
# 1983   M  all  2005       47.8
# 1984   M  all  2006       47.6
# 1985   M  all  2007       47.4
# 1986   M  all  2008       47.2
# 1987   M  all  2009       47.0
# 1988   M  all  2010       46.8
# 1989   M  all  2011       46.6
# 1990   M  all  2012       46.5
# 1991   M  all  2013       46.3
# 1992   M  all  2014       46.2
# 1993   M  all  2015       46.1
# 1994   M  all  2016       46.0
# 1995   M  all  2017       45.8
# 1996   M  all  2018       45.7
# 1997   M  all  2019       45.6
# 1998   M  all  2020       45.6
# 1999   M  all  2021       45.6
# 2000   M  all  2022       45.6

# %%
df_age_to_group = df_age.dropna()
df_age_to_group
#without tot/ not group up yet
# Out:
#      SEX  AGE  CCYY  OBS_VALUE
# 0      M    0  2000        0.4
# 1      M    0  2001        0.3
# 2      M    0  2002        0.3
# 3      M    0  2003        0.3
# 4      M    0  2004        0.3
# ...   ..  ...   ...        ...
# 3974   F  85+  2018        1.8
# 3975   F  85+  2019        1.8
# 3976   F  85+  2020        1.9
# 3977   F  85+  2021        2.0
# 3978   F  85+  2022        2.0
#
# [3956 rows x 4 columns]

# %%
df_gender = gender_ratio.drop(['STAT_VAR','STAT_PRES','SD_VALUE'], axis=1)

# %%
df_gender
# Out:
#      AGE  CCYY  OBS_VALUE
# 0    0-4  2000       1086
# 1    0-4  2001       1086
# 2    0-4  2002       1074
# 3    0-4  2003       1073
# 4    0-4  2004       1081
# ..   ...   ...        ...
# 451  NaN  2019        910
# 452  NaN  2020        913
# 453  NaN  2021        910
# 454  NaN  2022        911
# 455  NaN  2023        909
#
# [456 rows x 3 columns]

# %%
df_LF.to_csv('df_LF.csv',index= False)
df_male_ratio.to_csv('df_male_ratio.csv',index= False)
df_female_ratio.to_csv('df_female_ratio.csv', index=False)
df_age_to_group.to_csv('df_age_to_group.csv', index= False)
df_gender.to_csv('df_gender.csv',index= False)

# %%
import zipfile

# Assuming you have multiple files to download
file_paths = ['df_LF.csv','df_male_ratio.csv','df_female_ratio.csv','df_age_to_group.csv','df_gender.csv']

# Create a zip file to contain all the files
with zipfile.ZipFile('files.zip', 'w') as zipf:
    for file in file_paths:
        zipf.write(file)

# Download the zip file
files.download('files.zip')
